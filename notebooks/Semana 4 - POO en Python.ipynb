# %% [markdown]
# # Clases y objetos en Python

# %% [markdown]
# Python es un lenguaje de programación orientado a objetos.
#
# Casi todo en Python es un objeto, con sus atributos y métodos.
#
# Una **clase** es como un constructor de objetos o un "modelo" para crear objetos.

# %% [markdown]
# ## Creando una clase en Python.

# %% [markdown]
# Para crear una clase, use la palabra reservada `class:`

# %%
# Ejemplo: crear una clase llamada 'MiClase' con un atributo llamado 'x'.

# %% [markdown]
# ## Creando un **objeto** en Python

# %% [markdown]
# ## La función `__init__()`

# %% [markdown]
# Los ejemplos anteriores son clases y objetos en su forma más simple y no son realmente útiles en aplicaciones de la vida real.
#
# Para comprender el significado de las clases, debemos comprender la función incorporada `__init__()`. A esta función se le conoce como el **constructor de la clase**.
#
# Todas las clases tienen una función llamada `__init__()`, que siempre se ejecuta cuando se inicia la clase.
#
# La función `__init__()` se usa para asignar valores a los atributos del objeto u otras operaciones que sean necesarias cuando se crea el objeto.

# %%
# Ejemplo: crear una clase llamada Persona y usar la función '__init__()' para
  # asignar valores para el nombre y la edad.

# %% [markdown]
# **Nota:** La función `__init__()` se llama automáticamente cada vez que se usa la clase para crear un nuevo objeto.

# %% [markdown]
# ## Métodos dentro de una clase

# %% [markdown]
# Los objetos también pueden contener métodos. Los métodos en los objetos son funciones que pertenecen al objeto.

# %%
# Ejemplo: insertar una función que imprima un saludo y ejecutarla en el objeto p1:

# %% [markdown]
# ## El parámetro `self`

# %% [markdown]
# El parámetro `self` es una referencia a la instancia actual de la clase y se utiliza para acceder a las variables que pertenecen a la clase.
#
# No tiene que llamarse `self` , puedes llamarlo como quieras, pero tiene que ser el primer parámetro de cualquier función en la clase.

# %%
# Ejemplo: usar las palabras miobjetocreado y abc en lugar de 'self':

# %% [markdown]
# ## Modificar atributos de los objetos

# %% [markdown]
# Python nos permite modificar el valor de los atributos de la clase.

# %%
# Ejemplo: de la clase 'Persona' modificar el atributo 'edad'.

# %% [markdown]
# **ACTIIVIDAD:** Crear una clase `Vehiculo` que reciba como parámetros el tipo de vehículo, el número de ruedas que tiene y el modelo de dicho vehículo. Dentro de la clase, crear dos métodos:
#
# 1.   `tipo_vehiculo()` que imprimirá el tipo de vehículo del usuario.
# 2.   `desplazamiento()` que imprimirá modelo del vehículo y el número de ruedas.
#
# Por ejemplo: Si mi vehículo es un carro, modelo Mazda, de 4 ruedas; al momento de crear el objeto de la clase se digitaría `Vehiculo("carro", "Mazda", 4)`

# %%
# Creamos la clase 'Vehículo'.

  # Contructor de la clase:

  # Método 'tipo_vehiculo()'

  # Método 'desplazamiento()'

# %%
# Función 'run()' y entry point.
def run():
  # Instanciamos la clase 'Vehiculo'

  # Llamamos el método 'tipo_vehiculo()'

  # Imprimimos el tipo vehículo y el modelo

  # Llamamos el método 'desplazamiento()'



if __name__ == '__main__':
    run()

# %% [markdown]
# **EJEMPLO:** Modelar con POO en Python una lámpara. La clase debe llamarse `Lamp` y debe tener los siguientes métodos `encender()`, `apagar()` y `mostrar_lampara()`. La lámpara, por defecto (al iniciar el programa), debe estar apagada; esto quiere decir que al crear el objeto debo digitar `Lamp(lampara_encendida=False)`
#
# La interacción del usuario con la lámapara debe realizarse por medio de un menú.

# %%
# Creamos la clase 'Lamp'.
class Lamp:
  _LAMPS = ['''
         .
    .    |    ,
     \   '   /
      ` ,-. '
   --- (   ) ---
        \ /
       _|=|_
      |_____|
  ''',
            '''
        ,-.
       (   )
        \ /
       _|=|_
      |_____|
  ''']

  # Método '__init__': constructor de la clase.

# %%
# Función 'run()' con menú y entry point.

# %% [markdown]
# # La herencia en Python

# %% [markdown]
# *   Permite la gerarquía de clases.
# *   Permite comparir comportamiento común en la gerarquía.
# *   Al padre se le conoce como *superclase* y al hijo como *subclase*.

# %%
# Creamos la clase 'Rectangulo'.

  # Definimos el método 'area()'


# Heredamos la clase 'Rectangulo' en la clase 'Cuadrado'.

# %%
def run():
  # Instanciamos la clase 'Rectángulo' con base de 3 y altura de 15

  # Imprimimos el área del rectángulo


  # Instanciamos la clase 'Cuadrado' con lado de 5

  # Imprimimos el área del cuadrado


if __name__ == '__main__':
  run()

# %% [markdown]
# ![m_merged.png](data:image/png;base64,...)

# %% [markdown]
# # Referencias

# %% [markdown]
# [1] [9.3. A First Look at Classes](https://docs.python.org/3/tutorial/classes.html?highlight=inheritance#a-first-look-at-classes)
#
# [2] [9.5. Inheritance](https://docs.python.org/3/tutorial/classes.html?highlight=inheritance#inheritance)

# %% [markdown]
# # Ejercicios de POO con soluciones

# %% [markdown]
# [1] [Ejercicios de Programación Orientada a Objetos en Python – 100 días de Python #11](https://programacionfacil.org/blog/ejercicios-de-programacion-orientada-a-objetos-en-python-100-dias-de-python-11/)
#
# [1.1] [Soluciones a los ejercicios anteriores](https://programacionfacil.org/blog/soluciones-de-ejercicios-de-programacion-orientada-a-objetos-100-dias-de-python-11/)
#
# [2] [Ejercicios de programación orientada a objetos](https://plataforma.josedomingo.org/pledin/cursos/programacion_python3/curso/u42/) En esta misma página encuentran un enlace a la solución de los ejercicios.
